# %% [markdown]
# # ***+++++++ Health Care Analysis +++++++***

# %% [markdown]
# ![AI-generated Doctor and Patient](hospital.jpg)

# %% [markdown]
# # ***Table of Contents :***

# %% [markdown]
# ##  ***1. Introduction:***
#
#  ***<div style="text-align: justify">Efficient resource allocation  and  timely  patient care are critical in modern healthcare systems. This project focuses on predicting the length of hospital stays for patients, leveraging machine learning   algorithms to analyze key features such as patient demographics, medical conditions, and clinical data. By identifying patterns and correlations within these features, the project aims to enhance healthcare management and improve patient outcomes.***
#
# ***<div style="text-align: justify">The dataset includes a rich variety of attributes—such as age, gender, blood type, medical condition, test results, admission type, and medication—that provide a comprehensive view of each patient's hospital journey. These features serve as inputs to predict , allowing healthcare facilities to anticipate patient needs, optimize workflows, and reduce bottlenecks in care delivery.***
#
# ***<div style="text-align: justify">Ultimately, this project seeks to bridge the gap between raw data and actionable insights, delivering innovative solutions for real-world challenges in hospital operations and patient care. By harnessing the power of machine learning, it contributes to the growing field of predictive analytics in healthcare.*** </div>

# %% [markdown]
# ## ***2.Goal of the project:***
# ***<div style="text-align: justify">To predict the length of hospital stays using machine learning, based on features like age, medical condition, test results, and admission details. The project aims to improve hospital resource planning, optimize patient care, reduce delays, and provide actionable insights for efficient healthcare management.*** </div>

# %% [markdown]
# ## ***3.Data Story***
#
# ## ***About Dataset:***
#
# ***<div style="text-align: justify">The healthcare dataset on data.world is a valuable resource for analyzing and improving various aspects of healthcare. It provides structured data that can be used to enhance patient outcomes, streamline clinical processes, and optimize healthcare operations*** </div>
#
# ***The Source of the data is from Data World***
#
#
# ***link:https://data.world/ninami/healthcare-dataset***
#
# ## ***Features/columns:***
#
# ***<div style="text-align: justify">1. encounter_id:
# This is a unique identifier for each hospital visit or interaction. It ensures that every record in our dataset is distinct.*** </div>
#
# ***<div style="text-align: justify">2. patient_id:
# A unique identifier for each patient. This can help link multiple visits for the same patient, which might be useful if you're analyzing patterns of repeated hospitalizations.*** </div>
#
# ***<div style="text-align: justify">3. name:
# The name of the patient is a descriptive field and is not relevant for analysis or predictions.*** </div>
# ***<div style="text-align: justify">4. age:
# This feature is highly significant. Age often correlates with health conditions, recovery rates, and length of stay. For instance, older patients may require longer stays due to slower recovery processes or underlying conditions.*** </div>
# ***<div style="text-align: justify">5. gender:
# Patient's gender, which could be relevant for gender-specific health studies*** </div>
# ***<div style="text-align: justify">6. blood_type:
# Blood type can be crucial in specific cases, such as surgeries or conditions requiring transfusions.*** </div>
# ***<div style="text-align: justify">7. medical_condition:
# This is a key feature. The diagnosis or condition of the patient directly impacts the length of stay, as more complex or severe conditions typically require longer hospitalizations. This column could also be used for grouping similar patient cases.*** </div>
# ***<div style="text-align: justify">8. doctor_id:
# A unique identifier for the doctor overseeing the patient. While it might not directly impact the length of stay, it could reveal trends linked to specific doctors, such as varying treatment approaches or specialties.*** </div>
# ***<div style="text-align: justify">9. doctor:
# The actual name of the doctor is more descriptive than analytical. It could be anonymized or replaced by doctor_id  to avoid privacy issues.*** </div>
# ***<div style="text-align: justify">10. hospital_id:
# A unique identifier for the hospital. If the dataset spans multiple hospitals, this feature could capture institutional differences, such as resources, specialties, or efficiency that might affect the length of stay.*** </div>
# ***<div style="text-align: justify">11. hospital:
# Similar to doctor, the hospital name is descriptive. Anonymized data or the hospital_id would typically be used for analysis.*** </div>
# ***<div style="text-align: justify">12. insurance_provider_id:
# This identifier can help analyze trends in insurance coverage. Patients with certain types of insurance may experience differences in treatment plans, hospital stay policies, or discharge procedures.*** </div>
#
# ***<div style="text-align: justify">13. insurance_provider:
# The name of the insurance provider adds context but is often not as directly useful as the insurance_provider_id.*** </div>
# ***<div style="text-align: justify">14. billing_amount:
# This feature provides insights into the cost of the hospital stay. It may correlate strongly with length of stay, as longer hospitalizations typically lead to higher bills. It could also serve as an auxiliary feature for cost-related analysis.*** </div>
# ***<div style="text-align: justify">15. room_number:
# The patient's room number during the stay, potentially useful for facility management.*** </div>
#
# ***<div style="text-align: justify">16. admission_type:
# This is a categorical feature indicating the nature of the admission (e.g., emergency, planned). Emergency admissions may correlate with longer stays due to the severity of cases, making this a useful feature for prediction.*** </div>
# ***<div style="text-align: justify">17. date_of_admission:
# This provides a timeline for the patient’s journey. It can be used to calculate length_of_stay the  when combined with discharge_date  and to analyze trends like seasonal spikes in admissions.*** </div>
# ***<div style="text-align: justify">18. discharge_date:
# When paired with , date_of_admission, this helps compute the target variable,length_of_stay . It is also useful for identifying the flow of patient discharges.*** </div>
# ***<div style="text-align: justify">19. medication:
# Medications prescribed during the hospital stay are important for understanding treatment plans. Certain medications may indicate more severe conditions that require longer stays.*** </div>
# ***<div style="text-align: justify">20. test_results:
# This feature reflects the outcomes of diagnostic tests. Abnormal results could point to complications, impacting the duration of a hospital stay. Including this data allows the model to capture health-related complexities.*** </div>
# ***<div style="text-align: justify">21. length_of_stay:
# This is the target variable for your project. It represents the total time a patient spends in the hospital, from admission to discharge. All the other features aim to predict this value.*** </div>

# %% [markdown]
# ***Importing Libraries***

# %%
import warnings #Used to manage warning messages in Python
import sys #Provides access to system-specific parameters and functions
if not sys.warnoptions:
    warnings.simplefilter("ignore")
import pandas as pd #A powerful library for data manipulation and analysis
import numpy as np #Focused on numerical computations. It provides support for arrays, matrices, and mathematical functions
import matplotlib.pyplot as plt #used for creating static, interactive, and animated visualizations like line plots, bar graphs, histograms, etc.
import seaborn as sns #this library simplifies creating visually appealing and informative statistical graphics such as heatmaps and pair plots
from scipy.stats import skew # tools for statistical computations such as calculating skewness, probability distributions, and hypothesis testing.
from sklearn.preprocessing import StandardScaler #Used for feature scaling in machine learning.
from sklearn.model_selection import train_test_split #Splits datasets into training and testing subsets
from sklearn.linear_model import LinearRegression #Implements a simple and commonly used linear regression algorithm for predicting continuous outcomes. 
                                                   # eg: predicting the length of hospital stays based on patient demographics and conditions

# %% [markdown]
# ***load data for pre proccessing***

# %%
# Specify the path to your CSV file
csv_file_path = ('C:/Users/asus/healthcare-dataset.csv')

# Load the CSV file into a DataFrame
df = pd.read_csv('healthcare-dataset.csv')

# Display the first few rows of the dataset
display(df.head(10))
# Out:
#    encounter_id  patient_id                 name  age  gender blood_type  \
# 0             1    48559735      Tiffany Ramirez   81  Female         O-
# 1             2    68988993          Ruben Burns   35    Male         O+
# 2             3    57429465            Chad Byrd   61    Male         B-
# 3             4    44487379    Antonio Frederick   49    Male         B-
# 4             5    57789449  Mrs. Brandy Flowers   51    Male         O-
# 5             6    92656382       Patrick Parker   41    Male        AB+
# 6             7    75616756       Charles Horton   82    Male        AB+
# 7             8    82900421         Patty Norman   55  Female         O-
# 8             9    43828145           Ryan Hayes   33    Male         A+
# 9            10    65979398         Sharon Perez   39  Female         O-
#
#   medical_condition  doctor_id           doctor  hospital_id  ...  \
# 0          Diabetes      24379   Patrick Parker         8130  ...
# ...

# %% [markdown]
# ***To print the dimensions of a DataFrame***

# %%
df.shape
# Out:
# (10000, 21)

# %% [markdown]
# ***To print the index range,column names & count of non_null  values***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   encounter_id           10000 non-null  int64
#  1   patient_id             10000 non-null  int64
#  2   name                   10000 non-null  object
#  3   age                    10000 non-null  int64
#  4   gender                 10000 non-null  object
#  5   blood_type             10000 non-null  object
#  6   medical_condition      10000 non-null  object
#  7   doctor_id              10000 non-null  int64
#  8   doctor                 10000 non-null  object
#  9   hospital_id            10000 non-null  int64
#  10  hospital               10000 non-null  object
#  11  insurance_provider_id  10000 non-null  int64
#  12  insurance_provider     10000 non-null  object
#  13  billing_amount         10000 non-null  float64
# ...

# %% [markdown]
# ***To get summary of statistical measures for the numerical columns***

# %%
df.describe()
# Out:
#        encounter_id    patient_id           age     doctor_id   hospital_id  \
# count   10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean     5000.50000  5.499700e+07     51.452200  55276.378200   5570.275300
# std      2886.89568  2.591835e+07     19.588974  26057.500342   2593.517205
# min         1.00000  1.000220e+07     18.000000  10039.000000   1000.000000
# 25%      2500.75000  3.262032e+07     35.000000  32990.250000   3347.750000
# 50%      5000.50000  5.523416e+07     52.000000  54996.500000   5610.000000
# 75%      7500.25000  7.735011e+07     68.000000  77987.250000   7835.250000
# max     10000.00000  9.999747e+07     85.000000  99997.000000   9997.000000
#
#        insurance_provider_id  billing_amount   room_number  length_of_stay
# count           10000.000000    10000.000000  10000.000000    10000.000000
# mean            55131.390700    25516.806778    300.082000       15.561800
# ...

# %% [markdown]
# ***To get the statistical summary for categorical columns***

# %%
df.describe(include=['object', 'category'])
# Out:
#                    name  gender blood_type medical_condition           doctor  \
# count             10000   10000      10000             10000            10000
# unique             9378       2          8                 6             9416
# top     Michael Johnson  Female        AB-            Asthma  Michael Johnson
# freq                  7    5075       1275              1708                7
#
#          hospital insurance_provider admission_type date_of_admission  \
# count       10000              10000          10000             10000
# unique       8639                  5              3              1815
# top     Smith PLC              Cigna         Urgent        2019-04-12
# freq           19               2040           3391                15
#
#        discharge_date  medication test_results
# count           10000       10000        10000
# unique           1834           5            3
# top        2021-11-28  Penicillin     Abnormal
# ...

# %% [markdown]
# # Data Cleaning:
# ***To print the number of missing (NaN) values in each column of the DataFrame***
# ***Remove all duplicate rows.***
# ***Treat the null values in all columns using any measures (removing/ replace the values with mean/median/mode)***
# ***Check the skewness***
# ***Find the outliers.***

# %%
#to print the number of missing (NaN) values in each column of the DataFrame
print(df.isnull().sum())
# Out:
# encounter_id             0
# patient_id               0
# name                     0
# age                      0
# gender                   0
# blood_type               0
# medical_condition        0
# doctor_id                0
# doctor                   0
# hospital_id              0
# hospital                 0
# insurance_provider_id    0
# insurance_provider       0
# billing_amount           0
# room_number              0
# admission_type           0
# date_of_admission        0
# discharge_date           0
# medication               0
# test_results             0
# length_of_stay           0
# dtype: int64

# %% [markdown]
# ***To print the duplicate record count and print the duplicate records***

# %%
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")

duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Number of duplicate rows: 0
# Empty DataFrame
# Columns: [encounter_id, patient_id, name, age, gender, blood_type, medical_condition, doctor_id, doctor, hospital_id, hospital, insurance_provider_id, insurance_provider, billing_amount, room_number, admission_type, date_of_admission, discharge_date, medication, test_results, length_of_stay]
# Index: []
#
# [0 rows x 21 columns]

# %%
print(df.dtypes)
# Out:
# encounter_id               int64
# patient_id                 int64
# name                      object
# age                        int64
# gender                    object
# blood_type                object
# medical_condition         object
# doctor_id                  int64
# doctor                    object
# hospital_id                int64
# hospital                  object
# insurance_provider_id      int64
# insurance_provider        object
# billing_amount           float64
# room_number                int64
# admission_type            object
# date_of_admission         object
# discharge_date            object
# medication                object
# test_results              object
# length_of_stay             int64
# dtype: object

# %% [markdown]
# ***print the skewness of the numerical columns***

# %%
columns_to_exclude = ['length_of_stay','test_results','medication','discharge_date','date_of_admission',
                      'admission_type','insurance_provider','hospital','doctor','medical_condition','blood_type','gender',
                     'name',]
skewness = df.drop(columns=columns_to_exclude, errors='ignore').skew()
print(skewness)
# Out:
# encounter_id             0.000000
# patient_id               0.002310
# age                     -0.012148
# doctor_id               -0.010543
# hospital_id             -0.038115
# insurance_provider_id   -0.029465
# billing_amount           0.012721
# room_number              0.013370
# dtype: float64

# %%
import matplotlib.pyplot as plt

columns_to_plot = ['encounter_id','patient_id','age','doctor_id','hospital_id', 'billing_amount', 'hospital_id']  # Replace with your numerical columns
for col in columns_to_plot:
    plt.figure()
    df[col].hist(bins=20, edgecolor='k')
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columns_to_plot = ['encounter_id','patient_id','age','doctor_id','hospital_id', 'billing_amount', 'hospital_id']  # Replace with your numerical columns
for col in columns_to_plot:
    plt.figure()
    sns.kdeplot(df[col], shade=True)
    plt.title(f"KDE Plot of {col}")

# %% [markdown]
# ***columns like enounter_id,patient_id,doctor_id,hospital_id,room_number are numeric, they can be excluded from statistical analyses like skewness because,these are identifiers rather than measured values.***
#
# ***In the dataset the remaining numerical columns are age,billing_amount and length_of_stay. length_of_stay also has to be excluded from statistical analyses since it is the target column.***

# %%
columns_to_plot = ['age', 'billing_amount',]  # Replace with your numerical columns
for col in columns_to_plot:
    plt.figure()
    sns.kdeplot(df[col], shade=True)
    plt.title(f"KDE Plot of {col}")

# %%
columns_to_plot = ['age', 'billing_amount', 'length_of_stay']  # Replace with your numerical columns
for col in columns_to_plot:
    plt.figure()
    df.boxplot(column=col)
    plt.title(f"Box Plot of {col}")
    plt.ylabel(col)
    plt.show()

# %%
categorical_columns = ['name', 'gender', 'blood_type', 'medical_condition']
for col in categorical_columns:
    print(df[col].value_counts())
# Out:
# name
# Michael Johnson        7
# James Johnson          6
# Michael Miller         4
# Michelle Williams      4
# Scott Smith            4
#                       ..
# Sharon Rose            1
# Stephanie Knox         1
# Anthony Jones          1
# Melissa Perkins DVM    1
# Eric King              1
# Name: count, Length: 9378, dtype: int64
# gender
# Female    5075
# Male      4925
# Name: count, dtype: int64
# blood_type
# AB-    1275
# AB+    1258
# B-     1252
# O+     1248
# O-     1244
# B+     1244
# A+     1241
# A-     1238
# Name: count, dtype: int64
# medical_condition
# Asthma          1708
# Cancer          1703
# Hypertension    1688
# Arthritis       1650
# Obesity         1628
# Diabetes        1623
# Name: count, dtype: int64
